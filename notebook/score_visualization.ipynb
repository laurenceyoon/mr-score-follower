# %%
# !which python
# Out:
# /Users/jiyun/.pyenv/versions/miniforge3-4.10.3-10/envs/msf/bin/python

# %%
import music21

# %%
score = music21.converter.parse("../resources/bwv66.6.musicxml")
score.show()

# %%
score.parts[0].measures(3, 5).show()

# %%
score.show()

# %%
from music21 import layout
pl = layout.PageLayout(pageNumber=4, leftMargin=234, rightMargin=124, pageHeight=4000, pageWidth=3000, isNew=True)

# %%
b = music21.corpus.parse('bach/bwv66.6')
b.show()

# %%
part1 = c.parts[0].measures(0, 2)

# %%
part1.getInstrument().instrumentName = "flute"

# %%
part1.show()

# %%
c.parts[1].measures(0, 2).show()

# %%
c.parts[2].measures(0, 2).show()

# %%
c.parts[3].measures(0, 2).show()

# %%
c.parts[0].measures(3, 6).show()

# %%
c.parts[1].measures(3, 5).show()

# %%
c.parts[2].measures(3, 5).show()

# %%
c.parts[3].measures(3, 5).show()
